# %% [markdown]
# <a href="https://colab.research.google.com/github/9159647312/E-Commerce-sales-performance-analysis/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Expense tracker

expenses = [150,100,200,30,500]

total= sum(expenses)
budget = 900

print("Total expenses:", total)
if total > budget:
  print("Over budget")
# Out:
# Total expenses: 980
# Over budget

# %%
#user defined function

def demo():
  print("hello")
demo()
# Out:
# hello

# %%
#with parameter

def demo(name):
  print("hello", name)
demo("john")
# Out:
# hello john

# %%
# return function

def add(a,b):
  return a+b

x= add(5,6)
print(x)
# Out:
# 11
