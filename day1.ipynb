# %% [markdown]
# <a href="https://colab.research.google.com/github/9159647312/E-Commerce-sales-performance-analysis/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#if else concept

m1= int(input("Enter M1:"))
m2= int(input("Enter M2:"))
m3= int(input("Enter M3:"))
m4= int(input("Enter M4:"))
m5= int(input("Enter M5:"))

marks= [m1,m2,m3,m4,m5]
total=sum(marks)
Avg= total/5

print("total:", total)
print("Average:", Avg)

if Avg>= 50:
  print("pass")
else:
  70
  print("Fail")
# Out:
# Enter M1:90
# Enter M2:89
# Enter M3:98
# Enter M4:79
# Enter M5:98
# total: 454
# Average: 90.8
# pass
