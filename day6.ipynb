# %% [markdown]
# <a href="https://colab.research.google.com/github/9159647312/E-Commerce-sales-performance-analysis/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Name: count, dtype: int64
#Day6 concept (Data-cleaning with pandas)

import pandas as pd

data = {
    "Name": ["Ak","raj","sam","tom","tyler"],
    "Age":[18,None,19,None,17]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name   Age
# 0     Ak  18.0
# 1    raj   NaN
# 2    sam  19.0
# 3    tom   NaN
# 4  tyler  17.0

# %%
import pandas as pd

data = {
    "Name": ["Ak","raj","sam","tom","tyler"],
    "Age":[18,None,19,None,17]
}

print(df.isnull())

null_age = df['Age'].isnull()
print("\n",null_age)

print("\n",df.isnull().sum())

count_age = df['Age'].isnull().sum()
print("\n",count_age)
# Out:
#     Name    Age
# 0  False  False
# 1  False   True
# 2  False  False
# 3  False   True
# 4  False  False
#
#  0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Age, dtype: bool
#
#  Name    0
# Age     2
# dtype: int64
#
#  2

# %%
import pandas as pd

data = {
    "Name": ["Ak","raj","sam","tom","tyler"],
    "Age":[18,None,19,None,17]
}

df = pd.DataFrame(data)
print(df.dropna())

age = df['Age'].dropna()
print("\n",age)
# Out:
#     Name   Age
# 0     Ak  18.0
# 2    sam  19.0
# 4  tyler  17.0
#
#  0    18.0
# 2    19.0
# 4    17.0
# Name: Age, dtype: float64

# %%
import pandas as pd

data = {
    "Name": ["Ak","raj","sam","tom","tyler"],
    "Age":[18,None,19,None,17]
}

df = pd.DataFrame(data)

print(df['Age'].fillna(0))
# Out:
# 0    18.0
# 1     0.0
# 2    19.0
# 3     0.0
# 4    17.0
# Name: Age, dtype: float64

# %%
import pandas as pd

data = {
    "Name": ["Ak","raj","sam","tom","tyler"],
    "Age": [18,None,19,None,17]
}

df = pd.DataFrame(data)

mean_age = df['Age'].mean()

df['Age'].fillna(mean_age,inplace=True)
print(df)
# Out:
#     Name   Age
# 0     Ak  18.0
# 1    raj  18.0
# 2    sam  19.0
# 3    tom  18.0
# 4  tyler  17.0
# /tmp/ipykernel_3002/3169793706.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(mean_age,inplace=True)
