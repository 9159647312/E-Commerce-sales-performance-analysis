# %% [markdown]
# <a href="https://colab.research.google.com/github/9159647312/E-Commerce-sales-performance-analysis/blob/main/day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Day7 concepts

#Data filtering & Transformation


import pandas as pd

data = {
    "Region" : ["North","South","East","West","North","South"],
    "Product":["LAP","MOBILE","LAP","TAB","MOBILE","TAB"],
    "Sales":[10000,20000,15000,30000,25000,35000]
}

df = pd.DataFrame(data)
print(df)

south_sales = df[df["Region"]=="South"]
print("\nSouth Region Sales:\n",south_sales)

#product_sales = df.groupby("Product")["Sales"].sum()
#print("\nProduct-wise Sales:\n",product_sales)

high_sales = df[df["Sales"]>15000]
print("\nProducts with sales greater than 15000:\n",high_sales)
# Out:
#   Region Product  Sales
# 0  North     LAP  10000
# 1  South  MOBILE  20000
# 2   East     LAP  15000
# 3   West     TAB  30000
# 4  North  MOBILE  25000
# 5  South     TAB  35000
#
# South Region Sales:
#    Region Product  Sales
# 1  South  MOBILE  20000
# 5  South     TAB  35000
#
# Products with sales greater than 15000:
#    Region Product  Sales
# 1  South  MOBILE  20000
# 3   West     TAB  30000
# 4  North  MOBILE  25000
# 5  South     TAB  35000

# %%
#sorting

sorted_df = df.sort_values("Sales") #for ascending
print(sorted_df)

dec_sort = df.sort_values(by="Sales",ascending=False)
print("\n",dec_sort)
# Out:
#   Region Product  Sales
# 0  North     LAP  10000
# 2   East     LAP  15000
# 1  South  MOBILE  20000
# 4  North  MOBILE  25000
# 3   West     TAB  30000
# 5  South     TAB  35000
#
#    Region Product  Sales
# 5  South     TAB  35000
# 3   West     TAB  30000
# 4  North  MOBILE  25000
# 1  South  MOBILE  20000
# 2   East     LAP  15000
# 0  North     LAP  10000
